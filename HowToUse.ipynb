# %% [markdown]
# # How to use SQLite3Handler

# %%
from SQLite3Handler import SQLite3Handler
import logging

import pandas as pd
import sqlite3

# %% [markdown]
# ## using logging.Logger.addHandler

# %%
# root Logger
logger = logging.getLogger()

# addHandler
logger.addHandler(SQLite3Handler('log.sqlite3'))

# setLevel
logger.setLevel('INFO')

# %%
# Level INFO
logger.info('Test1')

# Level ERROR
try:
    raise ValueError('Exception for Test2')
except ValueError:
    logger.exception('Test2')

# %%
# function for show table
def get_table(query: str, database: str) -> pd.DataFrame:
    connection = sqlite3.connect(database)
    tbl = pd.read_sql(query, connection, index_col='id')
    connection.close()
    return tbl

# %%
tbl = get_table('SELECT * FROM logs', 'log.sqlite3')
tbl
# Out:
#                           Time LoggerName  Level  \
# id
# 1   2019-10-22 22:36:06.967831       root   INFO
# 2   2019-10-22 22:36:07.131141       root  ERROR
#
#                           FileName  LineNo                      ModuleName  \
# id
# 1   <ipython-input-3-8eac08c60f43>       2  <ipython-input-3-8eac08c60f43>
# 2   <ipython-input-3-8eac08c60f43>       8  <ipython-input-3-8eac08c60f43>
#
#     FuncName  ProcessID  ProcessName  ThreadID  ThreadName LogMessage  \
# id
# 1   <module>      13644  MainProcess     13468  MainThread      Test1
# 2   <module>      13644  MainProcess     13468  MainThread      Test2
#
#    ExceptionType                                          TraceBack
# id
# 1           None                                               None
# 2     ValueError  Traceback (most recent call last):\n  File "<i...

# %%
# TraceBack
print(tbl.at[2, 'TraceBack'])
# Out:
# Traceback (most recent call last):
#   File "<ipython-input-3-8eac08c60f43>", line 6, in <module>
#     raise ValueError('Exception for Test2')
# ValueError: Exception for Test2

# %% [markdown]
# ## using logging.config.dictConfig

# %%
from logging.config import dictConfig

# %%
config = {
    'version': 1,
    'handlers': {
        'sqlite3': {
            'class': 'SQLite3Handler.SQLite3Handler',
            'database': 'log.sqlite3',
            'level': 'INFO'
        }
    },
    'loggers': {
        'sqlite3': {
            'level': 'INFO',
            'propagate': False,
            'handlers': ['sqlite3']
        }
    },
    'disable_existing_loggers': False
}

dictConfig(config)

# %%
# sqlite3 Logger
sqlite3_logger = logging.getLogger('sqlite3')
sqlite3_logger.info('Test3')

# %%
tbl = get_table('SELECT * FROM logs', 'log.sqlite3')
tbl
# Out:
#                           Time LoggerName  Level  \
# id
# 1   2019-10-22 22:36:06.967831       root   INFO
# 2   2019-10-22 22:36:07.131141       root  ERROR
# 3   2019-10-22 22:36:11.184121    sqlite3   INFO
#
#                           FileName  LineNo                      ModuleName  \
# id
# 1   <ipython-input-3-8eac08c60f43>       2  <ipython-input-3-8eac08c60f43>
# 2   <ipython-input-3-8eac08c60f43>       8  <ipython-input-3-8eac08c60f43>
# 3   <ipython-input-9-5a2199b5c653>       3  <ipython-input-9-5a2199b5c653>
#
#     FuncName  ProcessID  ProcessName  ThreadID  ThreadName LogMessage  \
# id
# 1   <module>      13644  MainProcess     13468  MainThread      Test1
# 2   <module>      13644  MainProcess     13468  MainThread      Test2
# 3   <module>      13644  MainProcess     13468  MainThread      Test3
#
#    ExceptionType                                          TraceBack
# id
# 1           None                                               None
# 2     ValueError  Traceback (most recent call last):\n  File "<i...
# 3           None                                               None
